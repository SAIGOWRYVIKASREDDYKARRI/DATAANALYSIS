# %%
import pandas as pd
a=['vikas',"abhiram",'prasanna','ayyappa']
r=pd.Series(a,index= [45,76,33,54])
print(r)
# Out:
# 45       vikas
# 76     abhiram
# 33    prasanna
# 54     ayyappa
# dtype: object

# %%
df=pd.read_csv("/content/abh.csv")
print(df)
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                    Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_excel("/content/abh_1.xlsx")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_excel("/content/abh_1.xlsx",sheet_name=0)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df.head( ))
print(df.tail(n=5))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df.describe())
# Out:
#             SEM1       SEM2      SEM3     Placed
# count  14.000000  17.000000  16.00000  17.000000
# mean    8.992857   9.000000   9.10000   0.588235
# std     0.929404   0.647109   1.05767   0.507300
# min     7.700000   8.000000   7.00000   0.000000
# 25%     8.000000   9.000000   9.20000   0.000000
# 50%     9.100000   9.100000   9.30000   1.000000
# 75%     9.800000   9.300000   9.90000   1.000000
# max     9.900000  10.000000  10.00000   1.000000

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df.describe().T)
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (17, 7)
# 17
# 7

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
l1=list(df.columns)
print(l1)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
df1=df.copy()
df1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
df1=df.copy()
df1.loc[2:5,'SEM1']=None
df1.head(7)
df1
#df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False   True  False  False  False   False
# 3  False     False   True  False   True  False   False
# 4  False     False   True  False  False  False   False
# 5  False     False   True  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
print(df1.isnull().sum())
#print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
print(df1.isnull().sum().sum())
# Out:
# 8

# %%
print(df['SEM1'])
print('***********************************')
print(df1['SEM1'])
# Out:
# 0     9.8
# 1     8.9
# 2     9.9
# 3     7.7
# 4     9.8
# 5     8.9
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64
# ***********************************
# 0     9.8
# 1     8.9
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
print(df[['SEM1','Names']])
print('**************************************')
print(df1[['SEM1','Names']])
# Out:
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    9.9  Kissan
# 3    7.7    Mary
# 4    9.8    Jeen
# 5    8.9     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark
# **************************************
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    NaN  Kissan
# 3    NaN    Mary
# 4    NaN    Jeen
# 5    NaN     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark

# %%
print(df[df.index==1])
print(df[df.index==4])
print(df[df.index==8])
print('*****************************************')
print(df1[df1.index==1])
print(df1[df1.index==4])
print(df1[df1.index==8])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 4  Jeen        K   9.8   9.1   9.9    A+       1
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 8  Jess        K   NaN   9.1   9.9    A+       1
# *****************************************
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 4  Jeen        K   NaN   9.1   9.9    A+       1
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 8  Jess        K   NaN   9.1   9.9    A+       1

# %%
print(df[df.index.isin(range(2,5))])
print('#######################################################################')
print(df1[df1.index.isin(range(2,5))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# #######################################################################
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   NaN   9.8  10.0     A       0
# 3    Mary        N   NaN   8.0   NaN     B       0
# 4    Jeen        K   NaN   9.1   9.9    A+       1

# %%
print(df.loc[4])
print('^^^^^^^^^^^^^^^^^^^^^^')
print(df1.loc[4])
# Out:
# Names       Jeen
# Initials       K
# SEM1         9.8
# SEM2         9.1
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 4, dtype: object
# ^^^^^^^^^^^^^^^^^^^^^^
# Names       Jeen
# Initials       K
# SEM1         NaN
# SEM2         9.1
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 4, dtype: object

# %%
#df.loc[6:11]
df.loc[[10,2,7]]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 7     Mari        N   7.7   8.0   7.1     B       1

# %%
df1.loc[10:15,[ 'Names','Grade']]
# Out:
#      Names Grade
# 10   Kiran     A
# 11    Maya     B
# 12   Jolin    A+
# 13  Rajesh     A
# 14    Riya     A
# 15    Sana     A

# %%
df1.iloc[10:14, :3]
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df1.loc[ :7, ["Names"]]
# Out:
#     Names
# 0     Joe
# 1  Rajesh
# 2  Kissan
# 3    Mary
# 4    Jeen
# 5     Raj
# 6  Hassan
# 7    Mari

# %%
df1.loc[df['Names']=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
df[df.Grade=='A']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
df[df.SEM2==10]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df.loc[df['SEM1']>9.8,['Names']]
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
df2=df1.copy()
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=df2.dropna()
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3=df1.copy()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2.dropna(inplace=True, axis=1)
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True, axis=1)
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df2.dropna(inplace=True,how='all')
df2
# Out:
# <ipython-input-43-2d07722aebd5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True,how='all')
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df4=df1.copy()
df4.iloc[2:3, :7]=None
df4.dropna(inplace=True,how='all')
df4
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+     1.0
# 1   Rajesh        M   8.9   9.1   9.3     A     1.0
# 3     Mary        N   NaN   8.0   NaN     B     0.0
# 4     Jeen        K   NaN   9.1   9.9    A+     1.0
# 5      Raj        M   NaN   9.1   9.3     A     1.0
# 6   Hassan        V   9.9   9.0   9.2     A     1.0
# 7     Mari        N   7.7   8.0   7.1     B     1.0
# 8     Jess        K   NaN   9.1   9.9    A+     1.0
# 9   Rajini        M   NaN   9.1   9.3     A     0.0
# 10   Kiran        V   NaN   9.3   9.2     A     0.0
# 11    Maya        N   7.7   8.0   7.1     B     0.0
# 12   Jolin        K   9.8   9.1   9.9    A+     1.0
# 13  Rajesh        M   8.9   9.1   9.3     A     1.0
# 14    Riya        M   9.3   9.9  10.0     A     1.0
# 15    Sana        V   9.9   9.3   9.2     A     0.0
# 16    Mark        N   7.7   8.0   7.0     B     0.0

# %%
df=pd.read_csv("/content/abh.csv",sep=" ")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
m=df['SEM1'].mean()
print(m)
df=df.fillna(m)
print(df)
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
df3=df.drop_duplicates()
print(df3)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
df=pd.read_excel("/content/book.xlsx",sheet_name=1)
print(df)
# Out:
#     aa
# 0   ug
# 1  jhg
